# %%
import pandas as pd

gdata = pd.read_xml('geographic_data.xml')
gdata.head()
# Out:
# /var/folders/sk/0xv6j3k50bdcv_wj6kkfqvk40000gn/T/ipykernel_7335/779007596.py:3: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   gdata = pd.read_xml('geographic_data.xml')
# Traceback (most recent call last):
#
#   File /opt/miniconda3/envs/api-visn/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 3
#     gdata = pd.read_xml('geographic_data.xml')
#
#   File /opt/miniconda3/envs/api-visn/lib/python3.12/site-packages/pandas/io/xml.py:1160 in read_xml
#     return _parse(
#
#   File /opt/miniconda3/envs/api-visn/lib/python3.12/site-packages/pandas/io/xml.py:852 in _parse
#     data_dicts = p.parse_data()
#
#   File /opt/miniconda3/envs/api-visn/lib/python3.12/site-packages/pandas/io/xml.py:556 in parse_data
# ...

# %%
import os
data_path = os.getcwd()+"Coding challenge/credit_history.parquet"
print(data_path)
pdata = pd.read_parquet(data_path)
pdata.head()
# Out:
# /Users/izzatillo_khazratov/Desktop/cbu-coding-challengeCoding challenge/credit_history.parquet
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 4
#       2 data_path = os.getcwd()+"Coding challenge/credit_history.parquet"
#       3 print(data_path)
# ----> 4 pdata = pd.read_parquet(data_path)
#       5 pdata.head()
#
# File /opt/miniconda3/envs/api-visn/lib/python3.12/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
# ...
